# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/raditya2010631170111/df_20111/main/oj.csv")
df
# Out:
#        store      brand  week    logmove  feat  price     AGE60      EDUC  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# ...      ...        ...   ...        ...   ...    ...       ...       ...
# 28942    137  dominicks   156   7.987524     0   2.00  0.209602  0.528362
# 28943    137  dominicks   157   8.502689     0   1.94  0.209602  0.528362
# 28944    137  dominicks   158   9.505991     0   1.59  0.209602  0.528362
# 28945    137  dominicks   159  10.927376     0   1.49  0.209602  0.528362
# 28946    137  dominicks   160   8.859363     0   1.75  0.209602  0.528362
#
#         ETHNIC     INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  \
# ...

# %%
df.groupby("brand").mean() 
df["brand"].value_counts()
# Out:
# tropicana      9649
# minute.maid    9649
# dominicks      9649
# Name: brand, dtype: int64

# %%
df["brand"].value_counts().plot.pie(autopct='%1.1f%%',labels=None, legend=True)
plt.tight_layout()

# %%
df_trop = df[df["brand"] == "tropicana"]
df_trop.head()
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5
# 0  0.376927
# 1  0.376927
# 2  0.376927
# ...

# %%
df_mm = df[df["brand"] == "minuted.maid"] 
df_mm

# %%
df_dm = df[df["brand"] == "dominicks"] 
df_dm

# %%
df_trop["logmove"].mean()

# %%
df.groupby(["brand", "week"])["logmove"].mean()
sns.scatterplot(x="week", y="logmove", data=df_trop, hue="brand")
plt.tight_layout()

# %%
df.groupby(["brand", "AGE60"])["logmove"].mean()
# Out:
# brand      AGE60
# dominicks  0.058054    9.365237
#            0.060280    8.833753
#            0.061954    9.528622
#            0.066896    9.314556
#            0.089724    9.435534
#                          ...
# tropicana  0.283728    9.495347
#            0.289442    9.075435
#            0.299353    9.376829
#            0.300279    9.726953
#            0.307398    9.360220
# Name: logmove, Length: 249, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.title("pengaruh usia penduduk di sekitar toko terhadap tingkat penjualan Tropicana")

sns.barplot(x=df_trop["AGE60"], y=df_trop["logmove"])
plt.xlabel("AGE60")
plt.ylabel("logmove")
Text(0, 0.5, "logmove")

# %%
df.groupby(["brand", "EDUC"])["logmove"].mean()

# %%
plt.figure(figsize=(10,6))
plt.title("pengaruh tingkat pendidikan penduduk di lingkungan toko dengan tingkat penjualan Tropicana")

sns.barplot(x=df_trop["EDUC"], y=df_trop["logmove"])
plt.xlabel("EDUC")
plt.ylabel("logmove")
Text(0, 0.5, "logmove")

# %%
df.groupby(["brand", "INCOME"])["logmove"].mean()

# %%
plt.figure(figsize=(10,6))
plt.title("pengaruh penghasilan rumah tangga di lingkungan toko dengan tingkat penjualan Tropicana")

sns.barplot(x=df_trop["INCOME"], y=df_trop["logmove"])
plt.xlabel("INCOME")
plt.ylabel("logmove")
Text(0, 0.5, "logmove")

# %%
sns.heatmap(data=df_trop[["INCOME","logmove", "AGE60", "EDUC"]].corr())
df[["INCOME","logmove", "AGE60", "EDUC"]].corr()
