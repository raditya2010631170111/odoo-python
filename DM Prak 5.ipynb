# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("https://raw.githubusercontent.com/raditya2010631170111/df_20111/main/Parkinsson%20disease.csv")
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
X = df.drop(['name', 'status'], axis=1)
y = df[['status']]

# %%
y.tail()
# Out:
#      status
# 190       0
# 191       0
# 192       0
# 193       0
# 194       0

# %%
X.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %% [markdown]
# There's no any single non-numerical data. So, we don't need to do any encode.

# %% [markdown]
# ## Variance Threshold

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
var_threshold = VarianceThreshold(threshold=0)

var_threshold.fit(X)
var_threshold.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
var_threshold = VarianceThreshold(threshold=0.1)

var_threshold.fit(X)
var_threshold.get_support()
# Out:
# array([ True,  True,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#         True, False,  True, False])

# %%
# low_var_cols_another = []

# for column in X.columns:
#     if column not in X.columns[var_threshold.get_support()]:
#         low_var_cols_another.append(column)

# for col in low_var_cols_another:
#     print(col, end=', ')
# Out:
# MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, MDVP:APQ, Shimmer:DDA, NHR, RPDE, DFA, spread2, PPE,

# %%
low_var_cols = [column for column in X.columns if column not in X.columns[var_threshold.get_support()]]

for col in low_var_cols:
    print(col)
# Out:
# MDVP:Jitter(%)
# MDVP:Jitter(Abs)
# MDVP:RAP
# MDVP:PPQ
# Jitter:DDP
# MDVP:Shimmer
# MDVP:Shimmer(dB)
# Shimmer:APQ3
# Shimmer:APQ5
# MDVP:APQ
# Shimmer:DDA
# NHR
# RPDE
# DFA
# spread2
# PPE

# %%
X_high = X.drop(low_var_cols, axis=1)

# %%
X_high.sample(5)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)     HNR   spread1        D2
# 79       100.770       115.697        85.545  19.200 -4.913885  2.398422
# 132      119.056       125.213        86.795  23.389 -5.436135  2.516320
# 4        116.014       141.781       110.655  19.649 -3.747787  2.332180
# 193      198.764       396.961        74.904  19.020 -6.744577  2.138608
# 159      127.930       138.752       112.173  19.651 -5.498456  2.103014

# %% [markdown]
# ## Chi-square

# %%
from sklearn.feature_selection import chi2

# %% [markdown]
# ### Load Dataset

# %%
df_bank = pd.read_csv('https://raw.githubusercontent.com/ammfat/datasets/main/BankChurners.csv')

df_bank.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df_bank.shape
# Out:
# (10127, 23)

# %% [markdown]
# ### Drop Unrequired Columns

# %%
df_bank.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
df_bank = df_bank.drop([
    'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1'
    , 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'
], axis=1)

df_bank.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [markdown]
# ### Identify Missing Values

# %%
df_bank.isnull().sum()

# %% [markdown]
# ### Drop Unrequired Columns

# %%
df_bank = df_bank.drop(['CLIENTNUM'], axis=1)

# %% [markdown]
# ### Data Transformation

# %%
df_bank.info()

# %%
df_bank.dtypes
# Out:
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
df_bank['Gender'].dtype
# Out:
# dtype('O')

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
# for col in df_bank.columns:
#     if df_bank[col].dtype == '0':
#         df_bank[col] = encoder.fit_transform(df_bank[col])

# %%
df_bank['Attrition_Flag'] = encoder.fit_transform(df_bank['Attrition_Flag'])
df_bank['Gender'] = encoder.fit_transform(df_bank['Gender'])
df_bank['Education_Level'] = encoder.fit_transform(df_bank['Education_Level'])
df_bank['Marital_Status'] = encoder.fit_transform(df_bank['Marital_Status'])
df_bank['Income_Category'] = encoder.fit_transform(df_bank['Income_Category'])
df_bank['Card_Category'] = encoder.fit_transform(df_bank['Card_Category'])

# %%
df_bank.tail()
# Out:
#        Attrition_Flag  Customer_Age  Gender  Dependent_count  Education_Level  \
# 10122               1            50       1                2                2
# 10123               0            41       1                2                6
# 10124               0            44       0                1                3
# 10125               0            30       1                2                2
# 10126               0            43       0                2                2
#
#        Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 10122               2                1              0              40
# 10123               0                1              0              25
# 10124               1                4              0              36
# 10125               3                1              0              36
# 10126               1                4              3              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %% [markdown]
# ### Chi-square test

# %%
X = df_bank.drop(["Attrition_Flag"], axis=1)
y = df_bank['Attrition_Flag']

# %%
chi_score = chi2(X, y)

chi_score

# %%
p_values = pd.Series(chi_score[1],index = X.columns)
p_values.sort_values(ascending = False , inplace = True)

# %%
p_values.plot.bar()

plt.show()

# %%
X = X.drop(['Education_Level', 'Card_Category', 'Marital_Status'], axis=1)

X.tail()
# Out:
#        Customer_Age  Gender  Dependent_count  Income_Category  Months_on_book  \
# 10122            50       1                2                1              40
# 10123            41       1                2                1              25
# 10124            44       0                1                4              36
# 10125            30       1                2                1              36
# 10126            43       0                2                4              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 10122                         3                       2
# 10123                         4                       2
# 10124                         5                       3
# 10125                         4                       3
# 10126                         6                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 10122                      3        4003.0                 1851
# ...

# %%
# df_parkinson = pd.read_csv('/content/drive/MyDrive/Aslab/2022 - TI 5D E - Data Mining/Parkinsson disease.xls')

# %%
# df_parkinson.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...
